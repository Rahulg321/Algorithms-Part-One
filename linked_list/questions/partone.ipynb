# %%
#Creating a general Linked List Class for our studies
#yield is a highly efficient genrator function
import random


class Node:
    def __init__(self, value) -> None:
        self.value = value
        self.next = None
        self.prev = None
    
    def __str__(self):
        return (str(self.value))


class LinkedList():
    
    def __init__(self):
        self.head = None
        self.tail = None
    
#this function makes our class iterable
    def __iter__(self):
        temp = self.head
        
        while temp:
            yield temp.value
            temp = temp.next
    
    def __str__(self) -> str:
        values = [str(x) for x in self]
        return ' -> '.join(values)

    def __len__(self):
        result = 0
        temp = self.head
        
        while temp:
            result += 1
            temp = temp.next
        
        return result

#creating a default add method, only adds a node to the end of the list
    def add(self, value):
        node = Node(value)
        if self.head is None:
            self.head = node
            self.tail = node
        else:
            self.tail.next = node
            self.tail = node
        
        return self.tail

#this func generates a random list for us 
    def generate_list(self, n, min_val, max_val):
        self.head = self.tail = None
        
        for _ in range(n):
            self.add(random.randint(min_val, max_val))
        
        return self
        

customLL = LinkedList()
customLL.generate_list(10,0,10)
print(customLL)
print(len(customLL))
# Out:
# 3 -> 2 -> 1 -> 9 -> 3 -> 8 -> 3 -> 9 -> 1 -> 6
# 10

# %%
"""_summary_

QUES 1:- Remove Duplicate Values from a LinkedList
My Method
    
"""


from random import randint


class Node:
    def __init__(self, value) -> None:
        self.value = value
        self.next = None
        self.prev = None
    
    def __str__(self):
        return (str(self.value))


class LinkedList():
    
    def __init__(self):
        self.head = None
        self.tail = None
    
#this function makes our class iterable
    def __iter__(self):
        temp = self.head
        
        while temp:
            yield temp.value
            temp = temp.next
    
    def __str__(self) -> str:
        values = [str(x) for x in self]
        return ' -> '.join(values)

    def __len__(self):
        result = 0
        temp = self.head
        
        while temp:
            result += 1
            temp = temp.next
        
        return result

#creating a default add method, only adds a node to the end of the list
    def add(self, value):
        node = Node(value)
        if self.head is None:
            self.head = node
            self.tail = node
        else:
            self.tail.next = node
            self.tail = node
        
        return self.tail

#this func generates a random list for us 
    def generate_list(self, n, min_val, max_val):
        self.head = self.tail = None
        
        for _ in range(n):
            self.add(randint(min_val, max_val))
        
        return self

    def delete_node(self, value):
        if self.head is None:
            print('The list is empty')
            return
        else:
            # values = [str(x) for x in self]
            temp = self.head
            
            while temp:
                if temp.value == value:
                    break
                prev_node = temp
                temp = temp.next
                
                
            
            if temp is None:
                print('The value does not exist in the list')
                return
            else:
                prev_node.next = temp.next
            
        
    
    
    def check_duplicates(self):
        values = [str(x) for x in self]
        
        new_values = []
        duplicates = []
        
        for x in values:
            if x in new_values:
                duplicates.append(x)
            else:
                new_values.append(x)
        
        for x in duplicates:
            self.delete_node(x)
    
    def without_duplicates(self):
        pass
        

customLL = LinkedList()
customLL.generate_list(10,0,10)
print(customLL)
print(len(customLL))


customLL.delete_node(0)

print(customLL)
# Out:
# 1 -> 5 -> 2 -> 1 -> 3 -> 5 -> 4 -> 7 -> 5 -> 3
# 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 120
#     116 print(customLL)
#     117 print(len(customLL))
# --> 120 customLL.delete_node(0)
#     122 print(customLL)
#
# Cell In[17], line 83, in LinkedList.delete_node(self, value)
#      80     prev_node = temp
#      81     temp = temp.next
# ---> 83     if temp.value == value:
#      84         break
#      86 if temp is None:
#
# AttributeError: 'NoneType' object has no attribute 'value'

# %%
nums = [1,1,2]

nums2 = []
duplicates = []

for x in nums:
    if x not in nums2:
        nums2.append(x)
    else:
        duplicates.append(x)
        

print(nums2)
print(duplicates)
# Out:
# [1, 2]
# [1]
