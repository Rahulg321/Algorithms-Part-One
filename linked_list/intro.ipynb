# %%
class Node:
    def __init__(self, value = None):
        self.value = value 
        self.next = None 
    
    
class linkedlist:
    def __init__(self):
        self.head = None
        self.tail = None
       
        
first = Node(34)
second = Node(56)
first.next = second
single_linked_list = linkedlist()

single_linked_list.head = first
single_linked_list.tail = second

# %%
#insertion operations in SingleLinkedList
class Node:
    def __init__(self, value = None):
        self.value = value 
        self.next = None 
    
    
class linkedlist:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def insert_at_beginning(self, value):
        new_node = Node(value)
        
        new_node.next = self.head
        self.head = new_node
        
    
    def insert_at_given(self, prev, value):
        """
        this function expects a previous node to be passed in as arguement
        """
        new_node = Node(value)
        
        new_node.next = prev.next
        prev.next = new_node
    
    def insert_at_end(self, value):
        new_node = Node(value)
        
        self.tail.next = new_node
        self.tail = new_node
        
    
    def print_list(self):
        temp = self.head
        
        while temp != None:
            print(temp.value)
            temp = temp.next
    
        
first = Node(34)
second = Node(56)
first.next = second
single_linked_list = linkedlist()

single_linked_list.head = first



single_linked_list.insert_at_beginning(68)
single_linked_list.insert_at_end(99)

single_linked_list.insert_at_given(prev = first, value = 'inserted at a given location')

#printing the list
single_linked_list.print_list()
# Out:
# 68
# 34
# inserted at a given location
# 56
# 99

# %%
#insertion operations in SingleLinkedList
#by maintaining a tail attribute and using a single function
class Node:
    def __init__(self, value = None):
        self.value = value 
        self.next = None 
    
    
class linkedlist:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def insert_node(self, value, location = None):
        new_node = Node(value)
#check whether list is empty or not 
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            #insert at the beginning
            if location == 0:
                new_node.next = self.head
                self.head = new_node
            #insert at the end
            elif location == -1:
                self.tail.next = new_node
                self.tail = new_node
            else:
            #inserting after a given location
                temp = self.head
                index = 0
                while index != location - 1:
                    temp = temp.next
                    index += 1
                    
                
                print(f'Value of temp is {temp.value}')
                next_node = temp.next
                temp.next = new_node
                new_node.next = next_node
                    
            
    def print_list(self):
        temp = self.head
        
        while temp != None:
            print(temp.value)
            temp = temp.next
        

single_linked_list = linkedlist()    
# first = Node(1)
# second = Node(2)

# single_linked_list.head = first
# single_linked_list.tail = second

# first.next = second


single_linked_list.insert_node(value = 1)
single_linked_list.insert_node(value = 2,location = -1)
single_linked_list.insert_node(value = 3,location = -1)
single_linked_list.insert_node(value = 4,location = -1)

single_linked_list.insert_node(value = 'inserted at position 3',location = 3)

print()
print()

#printing the list
single_linked_list.print_list()
# Out:
# Value of temp is 3
#
#
# 1
# 2
# 3
# inserted at position 3
# 4

# %%
#insertion operations in SingleLinkedList
#by maintaining a tail attribute and using a single function
class Node:
    def __init__(self, value = None):
        self.value = value 
        self.next = None 
    
    
class linkedlist:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def insert_node(self, value, location = None):
        new_node = Node(value)
#check whether list is empty or not 
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            #insert at the beginning
            if location == 0:
                new_node.next = self.head
                self.head = new_node
            #insert at the end
            elif location == -1:
                self.tail.next = new_node
                self.tail = new_node
            else:
            #inserting at a given location
                temp = self.head
                index = 1
                while index != location - 1:
                    temp = temp.next
                    index += 1
                    
                
                print(f'Value of temp is {temp.value}')
                next_node = temp.next
                temp.next = new_node
                new_node.next = next_node
                    
            
    def print_list(self):
        temp = self.head
        
        while temp != None:
            print(temp.value)
            temp = temp.next
        

single_linked_list = linkedlist()    


single_linked_list.insert_node(value = 1)
single_linked_list.insert_node(value = 2,location = -1)
single_linked_list.insert_node(value = 3,location = -1)
single_linked_list.insert_node(value = 4,location = -1)

single_linked_list.insert_node(value = 'inserted at position 3',location = 3)

print()
print()

#printing the list
single_linked_list.print_list()
# Out:
# Value of temp is 2
#
#
# 1
# 2
# inserted at position 3
# 3
# 4

# %%
#traversal of a single linked list

#insertion operations in SingleLinkedList
#by maintaining a tail attribute and using a single function
class Node:
    def __init__(self, value = None):
        self.value = value 
        self.next = None 
    
    
class linkedlist:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def insert_node(self, value, location = None):
        new_node = Node(value)
#check whether list is empty or not 
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            #insert at the beginning
            if location == 0:
                new_node.next = self.head
                self.head = new_node
            #insert at the end
            elif location == -1:
                self.tail.next = new_node
                self.tail = new_node
            else:
            #inserting at a given location
                temp = self.head
                index = 1
                while index != location - 1:
                    temp = temp.next
                    index += 1
                    
                
                print(f'Value of temp is {temp.value}')
                next_node = temp.next
                temp.next = new_node
                new_node.next = next_node
                    
            
    def traversal(self):
        
        temp = self.head
        #check if the list is empty
        if temp is None:
            return 'The single linked list does not exist'
        
        else:
            while temp != None:
                print(temp.value)
                temp = temp.next
        

single_linked_list = linkedlist()    
first = Node(1)
second = Node(2)
third = Node(3)
fourth = Node(4)


first.next = second
second.next = third
third.next = fourth

single_linked_list.head = first
single_linked_list.tail = fourth


#printing the list
single_linked_list.traversal()


#Time Complexity -> O(n) 
#Space Complexity -> O(1) creating only one temporary node
# Out:
# 1
# 2
# 3
# 4

# %%
#find an element in a single linked list

class Node:
    def __init__(self, value = None):
        self.value = value 
        self.next = None 
    
    
class linkedlist:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def search_inlist(self, value):
        """_summary_

        This is UDEMY's way of implementing the search operation
        """
        if self.head is None:
            return 'The list is empty, does not exist'
        else:
            temp = self.head
            while temp != None:
                if temp.value == value:
                    return temp.value
                temp = temp.next
            
            return 'The value does not exist'
                    
    
    def searching_node(self, value):
        """_summary_

       This is my way of implementing the search function
        """
        temp = self.head
        index = 1
        while temp != None:
            if temp.value == value:
                return f'node with value {value} found at index {index}'
            
            index += 1
            temp = temp.next
            
        
        return 'Element is not present in the list'
    
    def insert_node(self, value, location = None):
        new_node = Node(value)

        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            #insert at the beginning
            if location == 0:
                new_node.next = self.head
                self.head = new_node
            #insert at the end
            elif location == -1:
                self.tail.next = new_node
                self.tail = new_node
            else:
            #inserting at a given location
                temp = self.head
                index = 1
                while index != location - 1:
                    temp = temp.next
                    index += 1
                    
                
                print(f'Value of temp is {temp.value}')
                next_node = temp.next
                temp.next = new_node
                new_node.next = next_node
                    
            
    def traversal(self):
        
        temp = self.head
        #check if the list is empty
        if temp is None:
            return 'The single linked list does not exist'
        
        else:
            while temp != None:
                print(temp.value)
                temp = temp.next
        

single_linked_list = linkedlist()    
first = Node(1)
second = Node(2)
third = Node(33)
fourth = Node(4)


first.next = second
second.next = third
third.next = fourth

single_linked_list.head = first
single_linked_list.tail = fourth


#printing the list
single_linked_list.traversal()



print()
print('Applying the search Operation')
single_linked_list.search_inlist(333)


#Time Complexity -> O(n) 
#Space Complexity -> O(1) creating only one temporary node
# Out:
# 1
# 2
# 33
# 4
#
# Applying the search Operation
# 'The value does not exist'

# %%
#deletion of a node from a singly linked list

class Node:
    def __init__(self, value = None):
        self.value = value 
        self.next = None 
    
    
class linkedlist:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def search_inlist(self, value):
        """_summary_

        This is UDEMY's way of implementing the search operation
        """
        if self.head is None:
            return 'The list is empty, does not exist'
        else:
            temp = self.head
            while temp != None:
                if temp.value == value:
                    return temp.value
                temp = temp.next
            
            return 'The value does not exist'
                    
    def delete_node(self, location):
        """_summary_
        This is my VERSION OF THE FUNCTION
        
            this func expects the index of the node to be deleted+
            to be passed in as arguement starting from 1
        """
        
        if self.head is None:
            return 'List is already empty, cant delete more'
        else:
            # deleting at the beginning
            if location == 0:
         #check if there exist only one node in the list       
                if self.head == self.tail:
                    self.head = self.tail = None
                else:
                    self.head = self.head.next
                    
            elif location == -1:
                if self.head == self.tail:
                    self.head = self.tail = None
                else:
                    temp = self.head
                    while temp.next != self.tail:
                        temp = temp.next
                    
                    self.tail = temp
                    temp.next = None
            else:
                temp = self.head
                index = 1
                
                while index != location -1:
                    temp = temp.next
                    index += 1
                
                # nextNode = temp.next.next
                temp.next = temp.next.next
                
   
    def searching_node(self, value):
        """_summary_

       This is my way of implementing the search function
        """
        temp = self.head
        index = 1
        while temp != None:
            if temp.value == value:
                return f'node with value {value} found at index {index}'
            
            index += 1
            temp = temp.next
            
        
        return 'Element is not present in the list'
                    
            
    def traversal(self):
        
        temp = self.head
        #check if the list is empty
        if temp is None:
            return 'The single linked list does not exist'
        
        else:
            while temp != None:
                print(temp.value)
                temp = temp.next
        

single_linked_list = linkedlist()    
first = Node(1)
second = Node(2)
third = Node(3)
fourth = Node(4)


first.next = second
second.next = third
third.next = fourth

single_linked_list.head = first
single_linked_list.tail = fourth


single_linked_list.delete_node(2)


#printing the list
single_linked_list.traversal()



#Time Complexity -> O(n) 
#Space Complexity -> O(1) creating only one temporary node
# Out:
# 1
# 3
# 4

# %%
#deletion of the entire singly linked list

class Node:
    def __init__(self, value = None):
        self.value = value 
        self.next = None 
    
    
class linkedlist:
    def __init__(self):
        self.head = None
        self.tail = None
        
        
    def delete_entire_list(self):
        if self.head is None:
            return 'The SLL is already empty does not exist'
        else:
            self.head = self.tail = None
    
    def search_inlist(self, value):
        """_summary_

        This is UDEMY's way of implementing the search operation
        """
        if self.head is None:
            return 'The list is empty, does not exist'
        else:
            temp = self.head
            while temp != None:
                if temp.value == value:
                    return temp.value
                temp = temp.next
            
            return 'The value does not exist'
                    
    def delete_node(self, location):
        """_summary_
        This is my VERSION OF THE FUNCTION
        
            this func expects the index of the node to be deleted
            to be passed in as arguement starting from 1
        """
        
        if self.head is None:
            return 'List is already empty, cant delete more'
        else:
            # deleting at the beginning
            if location == 0:
         #check if there exist only one node in the list       
                if self.head == self.tail:
                    self.head = self.tail = None
                else:
                    self.head = self.head.next
                    
            elif location == -1:
                if self.head == self.tail:
                    self.head = self.tail = None
                else:
                    temp = self.head
                    while temp.next != self.tail:
                        temp = temp.next
                    
                    self.tail = temp
                    temp.next = None
            else:
                temp = self.head
                index = 1
                
                while index != location -1:
                    temp = temp.next
                    index += 1
                
                # nextNode = temp.next.next
                temp.next = temp.next.next
                
   
    def searching_node(self, value):
        """_summary_

       This is my way of implementing the search function
        """
        temp = self.head
        index = 1
        while temp != None:
            if temp.value == value:
                return f'node with value {value} found at index {index}'
            
            index += 1
            temp = temp.next
            
        
        return 'Element is not present in the list'
                    
            
    def traversal(self):
        
        temp = self.head
        #check if the list is empty
        if temp is None:
            return 'The single linked list does not exist'
        
        else:
            while temp != None:
                print(temp.value)
                temp = temp.next
        

single_linked_list = linkedlist()    
first = Node(1)
second = Node(2)
third = Node(3)
fourth = Node(4)


first.next = second
second.next = third
third.next = fourth

single_linked_list.head = first
single_linked_list.tail = fourth

single_linked_list.traversal()

print('deleting the entire list')
single_linked_list.delete_entire_list()


#printing the list
single_linked_list.traversal()



#Time Complexity -> O(1) 
#Space Complexity -> O(1) creating only one temporary node
# Out:
# 1
# 2
# 3
# 4
# deleting the entire list
# 'The single linked list does not exist'
